# %%
import requests
import json
from tqdm import notebook

# %%
scenedata = []

with open("./assets/hashlist.json") as fs:
    bb = json.loads(fs.read())
    for a in bb:
        if "SpecialSkills" in a['path']:
            continue
        url = f"https://cdn2-mistglobal-prod-ntk.azureedge.net/prod-client-web-assets-ntk1-8-1/{a['path']}" #big file test
        # Streaming, so we can iterate over the response.
        response = requests.get(url, stream=True)
        total_size_in_bytes= int(response.headers.get('content-length', 0))
        block_size = 1024 #1 Kibibyte
        progress_bar = notebook.tqdm(total=total_size_in_bytes, unit='B', unit_scale=True, desc=str({a['path']}))
        with open(f"./assets/{a['path']}", 'wb') as file:
            for data in response.iter_content(block_size):
                progress_bar.update(len(data))
                file.write(data)
        progress_bar.close()
        if total_size_in_bytes != 0 and progress_bar.n != total_size_in_bytes:
            print("ERROR, something went wrong")
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# d:\ProjectNutaku\MistTrainGirlsX\scraper.ipynb Cell 3' in <cell line: 3>()
#      <a href='vscode-notebook-cell:/d%3A/ProjectNutaku/MistTrainGirlsX/scraper.ipynb#ch0000001?line=10'>11</a> total_size_in_bytes= int(response.headers.get('content-length', 0))
#      <a href='vscode-notebook-cell:/d%3A/ProjectNutaku/MistTrainGirlsX/scraper.ipynb#ch0000001?line=11'>12</a> block_size = 1024 #1 Kibibyte
# ---> <a href='vscode-notebook-cell:/d%3A/ProjectNutaku/MistTrainGirlsX/scraper.ipynb#ch0000001?line=12'>13</a> progress_bar = notebook.tqdm(total=total_size_in_bytes, unit='B', unit_scale=True, desc={a['path']})
#      <a href='vscode-notebook-cell:/d%3A/ProjectNutaku/MistTrainGirlsX/scraper.ipynb#ch0000001?line=13'>14</a> with open(f"./assets/{a['path']}", 'wb') as file:
# ...

# %%
for a in scenedata:
    headers = {
        'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiI2MDQ0NTgiLCJjbnQiOiIzOSIsIl9fZ2FtZVZlcnNpb24iOiIyIiwiX191c2VyTG9naW5HYW1lRGF0ZSI6IjUvMTgvMjAyMiA1OjAwOjAwIEFNIiwibmJmIjoxNjUyODkyMDYwLCJleHAiOjE2NTI5Nzg0NjAsImlhdCI6MTY1Mjg5MjA2MCwiaXNzIjoia21zMy5jb20iLCJhdWQiOiJkbW0ifQ.fMIjs2Bmb8bkwcneb-6OVPu3g7FFRD4XjuU541w_sik'
    }
    resp = requests.get(f"https://fd-mistglobal-prod-ntk.azurefd.net/api/UScenes/{a}", headers=headers)
    with open(f"./scene/{a}", "w") as fs:
            fs.write(json.dumps(resp.json(), indent = 4))
    print(f"Scene {a} has been saved!")
# Out:
# Scene 300101 has been saved!
# Scene 300102 has been saved!
# Scene 300103 has been saved!
# Scene 300104 has been saved!
# Scene 300105 has been saved!
# Scene 300106 has been saved!
# Scene 300107 has been saved!
# Scene 300108 has been saved!
# Scene 300109 has been saved!
# Scene 300110 has been saved!
# Scene 300201 has been saved!
# Scene 300202 has been saved!
# Scene 300203 has been saved!
# Scene 300204 has been saved!
# Scene 300205 has been saved!
# Scene 300206 has been saved!
# Scene 300207 has been saved!
# Scene 300208 has been saved!
# Scene 300209 has been saved!
# Scene 300210 has been saved!
# Scene 300301 has been saved!
# Scene 300302 has been saved!
# Scene 300303 has been saved!
# Scene 300304 has been saved!
# Scene 300305 has been saved!
# Scene 300306 has been saved!
# Scene 300307 has been saved!
# Scene 300308 has been saved!
# Scene 300309 has been saved!
# Scene 300310 has been saved!
# Scene 300401 has been saved!
# Scene 300402 has been saved!
# ...
